# %%
import os
import pandas as pd
from matplotlib import pyplot as plt

# %%
os.getcwd()
# Out:
# 'E:\\20190923 Newcastle-M.Res\\OneDrive - Newcastle University\\21_22_autumn\\220802 Design Exchange Partnership\\0_paperFeiChen'

# %%
df = pd.read_csv('Data/site.csv') 
df.head()
# Out:
#         id                  name  comments  photos  time/person (mins)  \
# 0    PLOT1              OystonSt        29      56                 7.4
# 1    PLOT2             GasHolder        21      41                 6.7
# 2  PLOT3&4  NewCollege&Expansion        56     154                12.7
# 3    PLOT5           FerryStreet        34      73                 3.2
# 4    PLOT6            HartonQuay        48      89                 7.8
#
#    area (hecs)    min/hec
# 0     0.261825  28.263203
# 1     0.254365  26.340105
# 2     0.396548  32.026403
# 3     0.047027  68.046273
# 4     0.334655  23.307585

# %%
plt.figure(figsize=(16, 9))

# Plot the bar chart
plt.bar(df['name'], df['min/hec'], color = 'steelblue', edgecolor='black')

# Add labels and title
plt.xlabel('',fontsize=15)
plt.ylabel('Minutes/Hectare',fontsize=15)
plt.title('')
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=12)
plt.savefig('Figure/timeNormalised.png', bbox_inches='tight')

# %%
df['comments'].sum()
# Out:
# 275

# %%
df['photos'].sum()
# Out:
# 697

# %%
df['comments'].sum() + df['photos'].sum()
# Out:
# 972
